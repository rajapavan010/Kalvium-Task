# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S04.htm'
page_request = requests.get(url)
soup_elements= BeautifulSoup(page_request.text, 'html')

# %%
print(soup_elements)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link crossorigin="" href="css/leaflet.css" integrity="sha256-kLaT2GOSpHechhsozzB+flnD+zUyjE2LlfWPgU04xyI=" rel="stylesheet"/>
# <script crossorigin="" integrity="sha256-WBkoXOwTeyKclOHuWtc+i2uENFpDZ9YPdf5Hf+D7ewM=" src="js/leaflet.js"></script>
# <style>
#         #elector_geotagging {
#             background-color: #fff;
#         }
# .leaflet-bottom { display: none; }
#         /*.leaflet-control {
#             display: none;
#         }*/
#     </style>
# <title>Election Commission of India</title>
# <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C8JDA-BHWH8-9MQ5M-HKZCP-GH7SB",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"C8JDA-BHWH8-9MQ5M-HKZCP-GH7SB",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="m7m5jpixh5kkazubowma-f-24e05cada-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,_={"ak.v":"37","ak.cp":"1109753","ak.ai":parseInt("537121",10),"ak.ol":"0","ak.cr":24,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"169ec854","ak.r":43830,"ak.a2":e,"ak.m":"b","ak.n":"ff","ak.bpcip":"103.217.212.0","ak.cport":51450,"ak.gh":"23.63.84.156","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1719760280","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"86","ak.dpoabenc":"","ak.tf":i};if(""!==t)_["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))_["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(_)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:_,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <header class="header">
# <div class="logo-search">
# <div class="mob-btn"><img alt="" src="img/icons/menu.png"/></div>
# <div class="logo"><a href="index.htm"><img alt="" src="img/eci-logo.png"/></a></div>
# <div class="lft-menu">
# <div class="menu-close">X</div>
# <div class="menu-logo"><a href="index.htm"><img alt="" src="img/eci-logo.png"/></a></div>
# <ul>
# <li><a href="index.htm"><span><img alt="" src="img/icons/home.png"/></span> Home</a></li>
# <li><a href="./hi/partywiseresult-S04.htm"><span><img alt="" src="img/icons/language.png"/></span> Hindi</a></li>
# <li><a href="#" onclick="window.location.href=window.location.href"><span><img alt="" src="img/icons/refresh.png"/></span> Refresh</a></li>
# <li><img alt="" src="img/deshgarv-logo.png"/></li>
# </ul>
# </div>
# </div>
# </header>
# <div class="dis-info">
# <div class="container-fluid">
# <div class="dis-flex">
# <h6 class="mb-0 mx-2"><span> </span> Disclaimer:</h6>
# <p class="mb-0"> ECI is displaying the information as being filled in the system by the Returning Officers from their respective Counting Centres.The final data for each AC/PC will be shared in Form-20.</p>
# </div>
# </div>
# </div><!-- End of dis-info Div -->
# <main class="inner-content">
# <div class="page-title">
# <h1>General Election to Parliamentary Constituencies: Trends &amp; Results June-2024</h1>
# <h2><span> <strong> Bihar</strong> (Total PC - 40) </span></h2>
# </div>
# <div class="container-fluid">
# <div class="row justify-content-center">
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #39AC57">
# <h4>JD(U)</h4>
# <h2>12</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #ff944d">
# <h4>BJP</h4>
# <h2>12</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #A2006D">
# <h4>LJPRV</h4>
# <h2>5</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #D6901B">
# <h4>RJD</h4>
# <h2>4</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #19AAED">
# <h4>INC</h4>
# <h2>3</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #BA5860">
# <h4>CPI(ML)(L)</h4>
# <h2>2</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #9F8A25">
# <h4>HAMS</h4>
# <h2>1</h2>
# </div><!-- End of grid-box div -->
# </div>
# <div class="col-md-2 col-sm-6 col-12">
# <div class="grid-box gen inc-pty-bg" style="background-color: #8bb036">
# <h4>IND</h4>
# <h2>1</h2>
# </div><!-- End of grid-box div -->
# </div>
# </div>
# <section class="my-3">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-12">
# <div class="card custom-card shadow-sm card-hght">
# <div class="card-header">Party Wise Results</div>
# <div class="card-body parent-wrap">
# <div class="scroll-child">
# <div class="rslt-table teble-responsive">
# <table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Janata Dal  (United) - JD(U)</td>
# <td style="text-align:right">
# <a href="partywisewinresult-805S04.htm">12</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">12</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresult-369S04.htm">12</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">12</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Lok Janshakti Party(Ram Vilas) - LJPRV</td>
# <td style="text-align:right">
# <a href="partywisewinresult-3165S04.htm">5</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">5</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Rashtriya Janata Dal - RJD</td>
# <td style="text-align:right">
# <a href="partywisewinresult-1420S04.htm">4</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">4</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresult-742S04.htm">3</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">3</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)</td>
# <td style="text-align:right">
# <a href="partywisewinresult-545S04.htm">2</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">2</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Hindustani Awam Morcha (Secular) - HAMS</td>
# <td style="text-align:right">
# <a href="partywisewinresult-664S04.htm">1</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">1</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Independent - IND</td>
# <td style="text-align:right">
# <a href="partywisewinresult-743S04.htm">1</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">1</td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <th>Total</th>
# <th style="text-align:right">40</th>
# <th style="text-align:right">0</th>
# <th style="text-align:right">40</th>
# </tr>
# </tfoot>
# </table>
# </div><!-- End rslt-table Div -->
# </div><!-- End of scroll-child Div -->
# </div>
# </div>
# </div>
# <div class="col-md-6 col-12">
# <div class="card custom-card shadow-sm">
# <div class="card-header">Constituency Wise Results <select class="custom-select" id="ctl00_ContentPlaceHolder1_Result1_ddlState" name="state" onchange="return GetResult(this)" style="float: right;"> <option value=""> Select Constituency </option><option value="S049">Araria - 9</option><option value="S0432">Arrah - 32</option><option value="S0437">Aurangabad - 37</option><option value="S0427">Banka - 27</option><option value="S0424">Begusarai - 24</option><option value="S0426">Bhagalpur - 26</option><option value="S0433">Buxar - 33</option><option value="S0414">Darbhanga - 14</option><option value="S0438">Gaya - 38</option><option value="S0417">Gopalganj - 17</option><option value="S0421">Hajipur - 21</option><option value="S0436">Jahanabad - 36</option><option value="S0440">Jamui - 40</option><option value="S047">Jhanjharpur - 7</option><option value="S0435">Karakat - 35</option><option value="S0411">Katihar - 11</option><option value="S0425">Khagaria - 25</option><option value="S0410">Kishanganj - 10</option><option value="S0413">Madhepura - 13</option><option value="S046">Madhubani - 6</option><option value="S0419">Maharajganj - 19</option><option value="S0428">Munger - 28</option><option value="S0415">Muzaffarpur - 15</option><option value="S0429">Nalanda - 29</option><option value="S0439">Nawada - 39</option><option value="S042">Paschim Champaran - 2</option><option value="S0431">Patliputra - 31</option><option value="S0430">Patna Sahib - 30</option><option value="S0412">Purnia - 12</option><option value="S043">Purvi Champaran - 3</option><option value="S0423">Samastipur - 23</option><option value="S0420">Saran - 20</option><option value="S0434">Sasaram - 34</option><option value="S044">Sheohar - 4</option><option value="S045">Sitamarhi - 5</option><option value="S0418">Siwan - 18</option><option value="S048">Supaul - 8</option><option value="S0422">Ujiarpur - 22</option><option value="S0416">Vaishali - 16</option><option value="S041">Valmiki Nagar  - 1</option></select></div>
# <div class="card-body">
# <div class="map" id="elector_geotagging" style="width:100%;height:586px;"></div>
# <p style="float: right;font-size: 11px;margin-bottom: -10px;font-weight: 500;">Not to Scale</p>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-12">
# <div class="card custom-card shadow-sm">
# <div class="card-header">Party Wise Vote Share</div>
# <div class="card-body">
# <div class="chart-wrap">
# <canvas id="piChart" style="max-width: 545px; width: 100%; max-height: 545px; height: 100%;"></canvas>
# </div><!-- End of chart wrap Div-->
# </div>
# </div>
# </div>
# <div class="col-md-6 col-12">
# <div class="card custom-card shadow-sm">
# <div class="card-header">Party Wise Results</div>
# <div class="card-body">
# <div class="chart-wrap">
# <canvas id="donutChart" style="max-width: 545px; width: 100%; max-height: 545px; height: 100%;"></canvas>
# </div><!-- End of chart wrap Div-->
# </div>
# </div>
# </div>
# </div><!-- End of row Div -->
# <h3 class="foot-title"><a class="btn btn-primary" href="statewiseS041.htm">All Constituencies at a glance <i>&gt;</i></a></h3>
# </div>
# </section>
# <footer class="footer">
# <div class="foot-info">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-12">
# <h6 class="mb-1">Download Voter helpline app to see results on mobile</h6>
# <div class="sm-text">Last Updated at 08:55 am On 05/06/2024</div>
# </div>
# <div class="col-md-6 col-12">
# <ul class="d-flex align-items-center items-end">
# <li><a href="https://play.google.com/store/apps/details?id=com.eci.citizen" target="_blank"><img alt="" src="img/icons/android.png"/></a></li>
# <li><a href="https://apps.apple.com/in/app/voter-helpline/id1456535004" target="_blank"><img alt="" src="img/icons/apple.png"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Optional JavaScript; choose one of the two! -->
# <script src="js/jquery-3.6.4.min.js" type="text/javascript"></script>
# <script src="js/jquery-3.1.1.min.js" type="text/javascript"></script>
# <!-- Option 1: Bootstrap Bundle with Popper -->
# <script src="js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <!-- Option 3: Custom jQuery Lab -->
# <script src="js/custom-jQuery.js" type="text/javascript"></script>
# <!-- Chart jQuery Lab -->
# <script src="js/chart.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function GetResult(ddstate) {
#                 var statecode = ddstate.value;
#                 if (statecode != 'Select State')
#                     location.href = 'candidateswise-' + statecode + '.htm';
#                 else
#                     location.href = 'candidateswise' + ddstate.options[1].value + '.htm';
#             }
#             function SetSelectedSate() {
#                 var ddlState = document.getElementById('ctl00_ContentPlaceHolder1_Result1_ddlState');
#                 var stateCode = '';
#                 var queryString = location.search.substring(1);
#                 if (queryString != null && queryString != '') {
#                     stateCode = queryString.split('=')[1];
#                 }
#                 if (ddlState != null)
#                     for (var index = 0; index < ddlState.options.length; index++) {
#                         if (ddlState.options[index].value == stateCode) {
#                             ddlState.options[index].selected = true;
#                         }
#                     }
#             }
#             onload = SetSelectedSate;
#
#         </script>
# <script src="pc/S04.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var lead_can_party;
#     var colorArr;
#     var mapstcode;
#     var count;
#     const SVGAPIURL = 'election-json-S04-live.json';
#     var colorsss = {};
#     var tableData = '';
#     var geoJson = '';
#     var lead_cand_party = '';
#     var lead_cand_name = '';
#
#     $(document).ready(function() {
#
#         fetch(SVGAPIURL)
#             .then(res => res.json())
#             .then(sdata => {
#                 try {
#                     const data = sdata;
#                     colorsss = data.S04.chartData;
#                     tableData = data.S04.tableData;
#                     //console.log(colorsss);
#                 } catch (e) {}
#
#             });
#
#         var map = L.map('elector_geotagging', {
#             center: [25.0961, 85.3131],
#             zoom: 8,
#             scrollWheelZoom: false,
#             doubleClickZoom: false,
#             cursor: true
#         });
#
#
#         var bounds_group = new L.featureGroup([]);
#         map.createPane('pane_All_AC');
#         map.getPane('pane_All_AC').style.zIndex = 400;
#         map.getPane('pane_All_AC').style['mix-blend-mode'] = 'normal';
#
#         setTimeout(function() {
#             var layer_All_AC = new L.geoJson(json_All_AC, {
#                 attribution: '',
#                 interactive: true,
#                 dataVar: 'json_All_AC',
#                 layerName: 'layer_All_AC',
#                 pane: 'pane_All_AC',
#                 onEachFeature: pop_All_AC,
#                 style: style_All_AC,
#             });
#             bounds_group.addLayer(layer_All_AC);
#             map.addLayer(layer_All_AC);
#
#
#
#
#             function style_All_AC(feature, layer) {
#                 var color = '#DDDDDD';
#                 var ac_no = feature.properties.PC_No;
#                 var state_code = feature.properties.ST_CODE;
#                 var new_combination = state_code + '_' + ac_no;
#                 //S29_11
#
#                 $.each(colorsss, function(index, value) {
#                     var new_sate = value[1];
#                     var new_ac = value[2];
#                     var combination = new_sate + '_' + new_ac;
#                     //console.log(combination);
#                     console.log('(combination',combination);
#                     if (new_combination == combination) {
#                         color = value[4];
#                         lead_cand_party = value[0];
#                         lead_cand_name = value[3];
#                         //console.log(color);
#                     }
#                     if(new_combination == 'U08_0'){
#                         color = '#00ffff';
#                     }
#
#                 });
#
#
#                 return {
#                     pane: 'pane_All_AC',
#                     opacity: 1,
#                     color: '#fff',
#                     dashArray: '',
#                     lineCap: 'butt',
#                     lineJoin: 'miter',
#                     weight: 1.0,
#                     fill: true,
#                     fillOpacity: 1,
#                     fillColor: color,
#                     interactive: true,
#                 }
#             }
#         }, 1000);
#
#         function pop_All_AC(feature, layer) {
#
#
#             var ac_no = feature.properties.PC_No;
#             var state_code = feature.properties.ST_CODE;
#             var new_combination = 'S' + state_code + '_' + ac_no;
#
#
#             if (feature.properties.PC_NAME != '') {
#                 var popup = '';
#             popup = '<div class="el-cons-tooltip" id="tooltip2" style="z-index: 999999999; display: block; top: 380px; left: 200px;" svgid="2"><div class="el-tip-cons" id="tl_cons_name2">Pc Name : '+feature.properties.PC_NAME+'</div><div id="tooltipdata2"><div class="el-tip"><div class="el-con-detail"><div class="el-con-name"> Party Name: '+lead_cand_party+'</div></div><div class="el-candidate-status won">Candidate Name: '+lead_cand_name+'</div></div></div></div>'
#
#             layer.bindPopup(popup, {
#                 maxHeight: 400,
#             });
#             layer.openTooltip(popup, {
#                 maxHeight: 400,
#             });
#             layer.on('mouseover', function() {
#                 layer.openPopup();
#             });
#             layer.on('mouseout', function() {
#                 layer.closePopup();
#             });
#         }
#
#             layer.addEventListener('click', function(event) {
#                 ac_no = (state_code == 'U08' || state_code == 'U09' && feature.properties.PC_NAME != '') ? 1 : ac_no;
#                 layer.preventDefault(window.location = 'candidateswise-' + state_code + ac_no + '.htm');
#
#             });
#         }
#     });
# </script>
# <script type="text/javascript">
#     // Doughnut Charts Starts Here
#     var xValues = ['BJP','CPI(ML)(L)','HAMS','INC','IND','JD(U)','LJPRV','RJD',];
#     var yValues = [12,2,1,3,1,12,5,4,];
#     var barColors = ['#ff944d','#BA5860','#9F8A25','#19AAED','#8bb036','#39AC57','#A2006D','#D6901B',];
#
#     new Chart("donutChart", {
#         type: "doughnut",
#         data: {
#             labels: xValues,
#             datasets: [{
#                 backgroundColor: barColors,
#                 data: yValues
#             }]
#         },
#         options: {
#             responsive: true,
#             plugins: {
#                 legend: {
#                     position: 'bottom',
#                 },
#                 title: {
#                     display: true,
#                     text: ''
#                 }
#             }
#         },
#     });
#
#
#     // Pi Charts Starts Here
#     var xValues = ['AIFB{0.02%}','AIMIM{0.88%}','BJP{20.52%}','BSP{1.75%}','CPI{1.30%}','CPI(M){0.87%}','CPI(ML)(L){2.99%}','INC{9.20%}','JD(U){18.52%}','LJPRV{6.47%}','NOTA{2.07%}','RJD{22.14%}','Others{13.27%}',];
#     var yValues = [8147,382214,8885818,757711,564310,375988,1293538,3983882,8020732,2803936,897323,9588365,5748007,];
#     var barColors = ['#ff3333','#00664d','#ff944d','#000078','#e70d21','#FF1D15','#BA5860','#19AAED','#39AC57','#A2006D','#ff6384','#D6901B','#b3b3b3',];
#     new Chart("piChart", {
#         type: "pie",
#         data: {
#             labels: xValues,
#             datasets: [{
#                 backgroundColor: barColors,
#                 data: yValues,
#                 borderWidth: [0]
#             }]
#         },
#         options: {
#             responsive: true,
#             plugins: {
#                 legend: {
#                     position: 'left',
#                 },
#                 title: {
#                     display: true,
#                     text: ''
#                 }
#             }
#         },
#     });
# </script>
# </div></main></body>
# </html>

# %%
soup_elements.find_all('table')
# Out:
# [<table class="table">
#  <thead>
#  <tr>
#  <th style="text-align: left;">Party</th>
#  <th style="text-align:right">Won</th>
#  <th style="text-align:right">Leading</th>
#  <th style="text-align:right">Total</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="tr">
#  <td style="text-align:left">Janata Dal  (United) - JD(U)</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-805S04.htm">12</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">12</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Bharatiya Janata Party - BJP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-369S04.htm">12</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">12</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Lok Janshakti Party(Ram Vilas) - LJPRV</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-3165S04.htm">5</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">5</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Rashtriya Janata Dal - RJD</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-1420S04.htm">4</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">4</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Indian National Congress - INC</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-742S04.htm">3</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">3</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-545S04.htm">2</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">2</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Hindustani Awam Morcha (Secular) - HAMS</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-664S04.htm">1</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">1</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Independent - IND</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-743S04.htm">1</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">1</td>
#  </tr>
#  </tbody>
#  <tfoot>
#  <tr>
#  <th>Total</th>
#  <th style="text-align:right">40</th>
#  <th style="text-align:right">0</th>
#  <th style="text-align:right">40</th>
#  </tr>
#  </tfoot>
#  </table>]

# %%
soup_elements.find_all('table', class_ = 'table')
# Out:
# [<table class="table">
#  <thead>
#  <tr>
#  <th style="text-align: left;">Party</th>
#  <th style="text-align:right">Won</th>
#  <th style="text-align:right">Leading</th>
#  <th style="text-align:right">Total</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="tr">
#  <td style="text-align:left">Janata Dal  (United) - JD(U)</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-805S04.htm">12</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">12</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Bharatiya Janata Party - BJP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-369S04.htm">12</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">12</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Lok Janshakti Party(Ram Vilas) - LJPRV</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-3165S04.htm">5</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">5</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Rashtriya Janata Dal - RJD</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-1420S04.htm">4</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">4</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Indian National Congress - INC</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-742S04.htm">3</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">3</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-545S04.htm">2</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">2</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Hindustani Awam Morcha (Secular) - HAMS</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-664S04.htm">1</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">1</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Independent - IND</td>
#  <td style="text-align:right">
#  <a href="partywisewinresult-743S04.htm">1</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">1</td>
#  </tr>
#  </tbody>
#  <tfoot>
#  <tr>
#  <th>Total</th>
#  <th style="text-align:right">40</th>
#  <th style="text-align:right">0</th>
#  <th style="text-align:right">40</th>
#  </tr>
#  </tfoot>
#  </table>]

# %%
election_table = soup_elements.find_all('table')

# %%
print(election_table)
# Out:
# [<table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Janata Dal  (United) - JD(U)</td>
# <td style="text-align:right">
# <a href="partywisewinresult-805S04.htm">12</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">12</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresult-369S04.htm">12</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">12</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Lok Janshakti Party(Ram Vilas) - LJPRV</td>
# <td style="text-align:right">
# <a href="partywisewinresult-3165S04.htm">5</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">5</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Rashtriya Janata Dal - RJD</td>
# <td style="text-align:right">
# <a href="partywisewinresult-1420S04.htm">4</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">4</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresult-742S04.htm">3</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">3</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)</td>
# <td style="text-align:right">
# <a href="partywisewinresult-545S04.htm">2</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">2</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Hindustani Awam Morcha (Secular) - HAMS</td>
# <td style="text-align:right">
# <a href="partywisewinresult-664S04.htm">1</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">1</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Independent - IND</td>
# <td style="text-align:right">
# <a href="partywisewinresult-743S04.htm">1</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">1</td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <th>Total</th>
# <th style="text-align:right">40</th>
# <th style="text-align:right">0</th>
# <th style="text-align:right">40</th>
# </tr>
# </tfoot>
# </table>]

# %%
for element in election_table:
    headers = element.find_all('th')

# %%
# Assuming headers is a list or a similar iterable
header_0 = headers[0]
header_1 = headers[1]
header_2 = headers[2]
header_3 = headers[3]

# Or, you can access them in one go using a tuple of indices
selected_headers_from_tabel = [headers[i] for i in [0, 1, 2, 3]]

# Print or use selected headers as needed
print(selected_headers_from_tabel)
# Out:
# [<th style="text-align: left;">Party</th>, <th style="text-align:right">Won</th>, <th style="text-align:right">Leading</th>, <th style="text-align:right">Total</th>]

# %%
attributes = [title.text.strip() for title in selected_headers_from_tabel]

print(attributes)
# Out:
# ['Party', 'Won', 'Leading', 'Total']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = attributes)
df
# Out:
# Empty DataFrame
# Columns: [Party, Won, Leading, Total]
# Index: []

# %%
for element in election_table:
    column_data = element.find_all('tr')

# %%
for row in column_data[1:-1]:  # Exclude the last row
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                                Party Won Leading Total
# 0                       Janata Dal  (United) - JD(U)  12       0    12
# 1                       Bharatiya Janata Party - BJP  12       0    12
# 2             Lok Janshakti Party(Ram Vilas) - LJPRV   5       0     5
# 3                         Rashtriya Janata Dal - RJD   4       0     4
# 4                     Indian National Congress - INC   3       0     3
# 5  Communist Party of India  (Marxist-Leninist)  ...   2       0     2
# 6            Hindustani Awam Morcha (Secular) - HAMS   1       0     1
# 7                                  Independent - IND   1       0     1

# %%
existing_data = pd.read_csv('lok_sabha_election_results.csv')

# Create two empty rows as a DataFrame
empty_rows = pd.DataFrame([[""] * len(existing_data.columns)] * 2, columns=existing_data.columns)

# Concatenate the existing data, empty rows, and new data
final_data = pd.concat([existing_data, empty_rows, df], ignore_index=True)

# Save the updated DataFrame back to the CSV file
final_data.to_csv('lok_sabha_election_results.csv', index=False)
